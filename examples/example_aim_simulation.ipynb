# %% [markdown]
# ### Anderson Impurity Model with Kanamori Interaction
#
# $$
# H = \sum_{m,\sigma} \varepsilon_{m0} n_{m0\sigma} + \sum_{m,l,\sigma} \varepsilon_{ml} n_{ml\sigma} + V_{ml} \left( c_{mo\sigma}^\dagger c_{ml\sigma} + h.c. \right) + H_{\rm DD} + H_{\rm SF-PH}
# $$
#
# $$
# H_{\rm DD} = U \sum_m n_{m0\uparrow}n_{m0\downarrow} + U'\sum_{m'> m }\sum_{\sigma} n_{m0\sigma} n_{m'0\bar{\sigma}} + (U'-J) \sum_{m'>m}\sum_{\sigma} n_{m0\sigma} n_{m'0\sigma}
# $$
#
# $$
# H_{\rm SF-PH} = \sum_{m'>m} \left[ J\left( c_{m0\uparrow}^\dagger c_{m0\downarrow} c_{m'0\uparrow} c_{m'0\downarrow}^\dagger + h.c. \right) - J\left( c_{m0\uparrow}^\dagger c_{m0\downarrow}^\dagger c_{m'0\uparrow} c_{m'0\downarrow} + h.c. \right) \right]
# $$

# %%
# Read source code

include("../models/AndersonImpurityModel.jl")
using .AndersonImpurityModel

include("../src/ForkTensorNetworks.jl")
using .ForkTensorNetworks

# %%
# Prepare FTNO & Initial FTNS for Anderson Impurity Model
# See reference SciPost Phys. 8, 024 (2020)

N_orb = 2               # Number of orbitals
N_bath = 9              # Number of bath sites
ρ = 0.5                 # Filling of the Impurity model (NOT impurity site)
U = 1.0                 # Coulomb repulsion
J = 0.1                 # Spin-flip, pair-hopping term
U′  = U - 2*J           # Coulomb repulsion for different orbital

εₖ = zeros( 2 * N_orb, N_bath + 1 )
for l=1:(2*N_orb)
    for k=1:N_bath
        εₖ[l,2:(N_bath+1)] = collect(range(-0.8, stop=0.8, length=N_bath))
    end
    εₖ[l,1] = -(3*U - 5*J)/2.
end
Vₖ = 0.1 * ones( 2 * N_orb, N_bath + 1 )


model_params = Dict(
    "model" => "AndersonImpurity",
    "N_orb" => N_orb,
    "N_bath" => N_bath,
    "εₖ" => εₖ,
    "Vₖ" => Vₖ,
    "U" => U,
    "U′" => U′,
    "J" => J,
    "ρ" => ρ,
    "conserve_qns" => true # false: No symmetry, true: U(1)xU(1) symmetry
)

Ws, phys_idx, ftno_aux_x_idx, ftno_aux_y_idx = ftno_aim_model(model_params);
Ts, ftns_aux_x_idx, ftns_aux_y_idx = ftns_initial_state(phys_idx, model_params["ρ"]; conserve_qns=model_params["conserve_qns"]);

# %%
#  Running DMRG to get the ground state of the Anderson Impurity Model

Ĥ = ForkTensorNetworkOperator(Ws, phys_idx, ftno_aux_x_idx, ftno_aux_y_idx);
ψ = ForkTensorNetworkState(Ts, phys_idx, ftns_aux_x_idx, ftns_aux_y_idx);

dmrg_params = Dict(
    "method" => "single-site",     # option: "single-site", "two-site"
    "χˣ" => 20,                    # Maximum bond dimension for the backbone
    "χʸ" => 20,                    # Maximum bond dimension for the arm
    "max_iter" => 100,             # Maximum number of DMRG sweeps
    "svd_tol" => 1e-10,            # Threshold for truncating singular values
    "convergence_tol" => 1e-10,    # Threshold for energy convergence
    "verbose" => true,             # Print information during DMRG sweeps
    "subspace_expansion" => true,  # Use subspace expansion or not (Highly recommended for the single-site DMRG)
    "α" => 0.1,                    # subspace expansion parameter
    "α_decay" => 0.5               # Must be less than or equal to 1.0
)

dmrg = DMRG(dmrg_params);
@time E, ψ = run_dmrg!(dmrg, Ĥ, ψ);
# Out:
# * DMRG Parameters:
# *  subspace_expansion: true
# *  svd_tol: 1.0e-10
# *  method: single-site
# *  χˣ: 20
# *  max_iter: 100
# *  α_decay: 0.5
# *  verbose: true
# *  convergence_tol: 1.0e-10
# *  α: 0.1
# *  χʸ: 20
#
# Iteration: 1, Energy: -9.254177382771719, δE: 1.0
# Iteration: 2, Energy: -10.110425720695552, δE: 0.08468964231359069
# Iteration: 3, Energy: -10.135410635597934, δE: 0.002465111261957995
# Iteration: 4, Energy: -10.135448893384597, δE: 3.774651430394994e-6
# Iteration: 5, Energy: -10.135449088245258, δE: 1.9225656331924554e-8
# Iteration: 6, Energy: -10.135449118942207, δE: 3.0286718055101013e-9
# Iteration: 7, Energy: -10.13544915413408, δE: 3.4721571774500937e-9
# Iteration: 8, Energy: -10.135449164936237, δE: 1.0657798401445582e-9
# Iteration: 9, Energy: -10.13544916618747, δE: 1.2345124155174357e-10
# Iteration: 10, Energy: -10.135449169875852, δE: 3.639089984305091e-10
# Iteration: 11, Energy: -10.135449172471215, δE: 2.5606797287518053e-10
# Iteration: 12, Energy: -10.135449173225599, δE: 7.443017173321944e-11
#  66.839607 seconds (105.11 M allocations: 8.908 GiB, 3.93% gc time, 96.50% compilation time: <1% of which was recompilation)

# %%
tdvp_params = Dict(
    "method" => "single-site",   # option: "single-site", "two-site"
    "χˣ" => 30,                  # Maximum bond dimension for the backbone
    "χʸ" => 30,                  # Maximum bond dimension for the arm
    "verb_level" => 0,           # Print information during TDVP sweeps (0: no print, 1: print params, 2: print details)
    "δt" => 0.10,                # Time step
    "Ncut" => 10,                # Maximum number of Kyrlov vectors used in the Kylov exponentiation
)

tdvp = TDVP(tdvp_params);
ψₜ = deepcopy(ψ);
ψ′ = deepcopy(ψ);
applying_local_operators!(ψₜ, [(1, 1, "c†")])
applying_local_operators!(ψ′, [(1, 1, "c†")])

Gₜ = [overlap_ftn(ψ′, ψₜ) * exp(1im * E * tdvp.time)]
Gₜ′ = [overlap_ftn(ψ′, ψₜ)* exp(1im * E * tdvp.time)]
Ts = [0.0]

for i = 1:150
    run_tdvp!(tdvp, Ĥ, ψₜ, 1)
    auto_corr = overlap_ftn(ψ′, ψₜ)
    append!(Gₜ, auto_corr * exp(-1im * E * tdvp.time))
    append!(Gₜ′, auto_corr)
    append!(Ts, tdvp.time)
end
# Out:
# * TDVP Parameters:
# *  δt: 0.1
# *  method: single-site
# *  χˣ: 30
# *  Ncut: 10
# *  verb_level: 0
# *  χʸ: 30
#
# * TDVP starts at time 0.00...
# * TDVP ends at time 0.10...
# * TDVP starts at time 0.10...
# * TDVP ends at time 0.20...
# * TDVP starts at time 0.20...
# * TDVP ends at time 0.30...
# * TDVP starts at time 0.30...
# * TDVP ends at time 0.40...
# * TDVP starts at time 0.40...
# * TDVP ends at time 0.50...
# * TDVP starts at time 0.50...
# * TDVP ends at time 0.60...
# * TDVP starts at time 0.60...
# * TDVP ends at time 0.70...
# * TDVP starts at time 0.70...
# * TDVP ends at time 0.80...
# * TDVP starts at time 0.80...
# * TDVP ends at time 0.90...
# * TDVP starts at time 0.90...
# * TDVP ends at time 1.00...
# * TDVP starts at time 1.00...
# * TDVP ends at time 1.10...
# * TDVP starts at time 1.10...
# * TDVP ends at time 1.20...
# * TDVP starts at time 1.20...
# * TDVP ends at time 1.30...
# * TDVP starts at time 1.30...
# * TDVP ends at time 1.40...
# * TDVP starts at time 1.40...
# * TDVP ends at time 1.50...
# * TDVP starts at time 1.50...
# * TDVP ends at time 1.60...
# * TDVP starts at time 1.60...
# * TDVP ends at time 1.70...
# * TDVP starts at time 1.70...
# * TDVP ends at time 1.80...
# * TDVP starts at time 1.80...
# * TDVP ends at time 1.90...
# * TDVP starts at time 1.90...
# * TDVP ends at time 2.00...
# * TDVP starts at time 2.00...
# * TDVP ends at time 2.10...
# * TDVP starts at time 2.10...
# * TDVP ends at time 2.20...
# * TDVP starts at time 2.20...
# * TDVP ends at time 2.30...
# * TDVP starts at time 2.30...
# * TDVP ends at time 2.40...
# * TDVP starts at time 2.40...
# * TDVP ends at time 2.50...
# * TDVP starts at time 2.50...
# * TDVP ends at time 2.60...
# * TDVP starts at time 2.60...
# * TDVP ends at time 2.70...
# * TDVP starts at time 2.70...
# * TDVP ends at time 2.80...
# * TDVP starts at time 2.80...
# * TDVP ends at time 2.90...
# * TDVP starts at time 2.90...
# * TDVP ends at time 3.00...
# * TDVP starts at time 3.00...
# * TDVP ends at time 3.10...
# * TDVP starts at time 3.10...
# * TDVP ends at time 3.20...
# * TDVP starts at time 3.20...
# * TDVP ends at time 3.30...
# * TDVP starts at time 3.30...
# * TDVP ends at time 3.40...
# * TDVP starts at time 3.40...
# * TDVP ends at time 3.50...
# * TDVP starts at time 3.50...
# * TDVP ends at time 3.60...
# * TDVP starts at time 3.60...
# * TDVP ends at time 3.70...
# * TDVP starts at time 3.70...
# * TDVP ends at time 3.80...
# * TDVP starts at time 3.80...
# * TDVP ends at time 3.90...
# * TDVP starts at time 3.90...
# * TDVP ends at time 4.00...
# * TDVP starts at time 4.00...
# * TDVP ends at time 4.10...
# * TDVP starts at time 4.10...
# * TDVP ends at time 4.20...
# * TDVP starts at time 4.20...
# * TDVP ends at time 4.30...
# * TDVP starts at time 4.30...
# * TDVP ends at time 4.40...
# * TDVP starts at time 4.40...
# * TDVP ends at time 4.50...
# * TDVP starts at time 4.50...
# * TDVP ends at time 4.60...
# * TDVP starts at time 4.60...
# * TDVP ends at time 4.70...
# * TDVP starts at time 4.70...
# * TDVP ends at time 4.80...
# * TDVP starts at time 4.80...
# * TDVP ends at time 4.90...
# * TDVP starts at time 4.90...
# * TDVP ends at time 5.00...
# * TDVP starts at time 5.00...
# * TDVP ends at time 5.10...
# * TDVP starts at time 5.10...
# * TDVP ends at time 5.20...
# * TDVP starts at time 5.20...
# * TDVP ends at time 5.30...
# * TDVP starts at time 5.30...
# * TDVP ends at time 5.40...
# * TDVP starts at time 5.40...
# * TDVP ends at time 5.50...
# * TDVP starts at time 5.50...
# * TDVP ends at time 5.60...
# * TDVP starts at time 5.60...
# * TDVP ends at time 5.70...
# * TDVP starts at time 5.70...
# * TDVP ends at time 5.80...
# * TDVP starts at time 5.80...
# * TDVP ends at time 5.90...
# * TDVP starts at time 5.90...
# * TDVP ends at time 6.00...
# * TDVP starts at time 6.00...
# * TDVP ends at time 6.10...
# * TDVP starts at time 6.10...
# * TDVP ends at time 6.20...
# * TDVP starts at time 6.20...
# * TDVP ends at time 6.30...
# * TDVP starts at time 6.30...
# * TDVP ends at time 6.40...
# * TDVP starts at time 6.40...
# * TDVP ends at time 6.50...
# * TDVP starts at time 6.50...
# * TDVP ends at time 6.60...
# * TDVP starts at time 6.60...
# * TDVP ends at time 6.70...
# * TDVP starts at time 6.70...
# * TDVP ends at time 6.80...
# * TDVP starts at time 6.80...
# * TDVP ends at time 6.90...
# * TDVP starts at time 6.90...
# * TDVP ends at time 7.00...
# * TDVP starts at time 7.00...
# * TDVP ends at time 7.10...
# * TDVP starts at time 7.10...
# * TDVP ends at time 7.20...
# * TDVP starts at time 7.20...
# * TDVP ends at time 7.30...
# * TDVP starts at time 7.30...
# * TDVP ends at time 7.40...
# * TDVP starts at time 7.40...
# * TDVP ends at time 7.50...
# * TDVP starts at time 7.50...
# * TDVP ends at time 7.60...
# * TDVP starts at time 7.60...
# * TDVP ends at time 7.70...
# * TDVP starts at time 7.70...
# * TDVP ends at time 7.80...
# * TDVP starts at time 7.80...
# * TDVP ends at time 7.90...
# * TDVP starts at time 7.90...
# * TDVP ends at time 8.00...
# * TDVP starts at time 8.00...
# * TDVP ends at time 8.10...
# * TDVP starts at time 8.10...
# * TDVP ends at time 8.20...
# * TDVP starts at time 8.20...
# * TDVP ends at time 8.30...
# * TDVP starts at time 8.30...
# * TDVP ends at time 8.40...
# * TDVP starts at time 8.40...
# * TDVP ends at time 8.50...
# * TDVP starts at time 8.50...
# * TDVP ends at time 8.60...
# * TDVP starts at time 8.60...
# * TDVP ends at time 8.70...
# * TDVP starts at time 8.70...
# * TDVP ends at time 8.80...
# * TDVP starts at time 8.80...
# * TDVP ends at time 8.90...
# * TDVP starts at time 8.90...
# * TDVP ends at time 9.00...
# * TDVP starts at time 9.00...
# * TDVP ends at time 9.10...
# * TDVP starts at time 9.10...
# * TDVP ends at time 9.20...
# * TDVP starts at time 9.20...
# * TDVP ends at time 9.30...
# * TDVP starts at time 9.30...
# * TDVP ends at time 9.40...
# * TDVP starts at time 9.40...
# * TDVP ends at time 9.50...
# * TDVP starts at time 9.50...
# * TDVP ends at time 9.60...
# * TDVP starts at time 9.60...
# * TDVP ends at time 9.70...
# * TDVP starts at time 9.70...
# * TDVP ends at time 9.80...
# * TDVP starts at time 9.80...
# * TDVP ends at time 9.90...
# * TDVP starts at time 9.90...
# * TDVP ends at time 10.00...
# * TDVP starts at time 10.00...
# * TDVP ends at time 10.10...
# * TDVP starts at time 10.10...
# * TDVP ends at time 10.20...
# * TDVP starts at time 10.20...
# * TDVP ends at time 10.30...
# * TDVP starts at time 10.30...
# * TDVP ends at time 10.40...
# * TDVP starts at time 10.40...
# * TDVP ends at time 10.50...
# * TDVP starts at time 10.50...
# * TDVP ends at time 10.60...
# * TDVP starts at time 10.60...
# * TDVP ends at time 10.70...
# * TDVP starts at time 10.70...
# * TDVP ends at time 10.80...
# * TDVP starts at time 10.80...
# * TDVP ends at time 10.90...
# * TDVP starts at time 10.90...
# * TDVP ends at time 11.00...
# * TDVP starts at time 11.00...
# * TDVP ends at time 11.10...
# * TDVP starts at time 11.10...
# * TDVP ends at time 11.20...
# * TDVP starts at time 11.20...
# * TDVP ends at time 11.30...
# * TDVP starts at time 11.30...
# * TDVP ends at time 11.40...
# * TDVP starts at time 11.40...
# * TDVP ends at time 11.50...
# * TDVP starts at time 11.50...
# * TDVP ends at time 11.60...
# * TDVP starts at time 11.60...
# * TDVP ends at time 11.70...
# * TDVP starts at time 11.70...
# * TDVP ends at time 11.80...
# * TDVP starts at time 11.80...
# * TDVP ends at time 11.90...
# * TDVP starts at time 11.90...
# * TDVP ends at time 12.00...
# * TDVP starts at time 12.00...
# * TDVP ends at time 12.10...
# * TDVP starts at time 12.10...
# * TDVP ends at time 12.20...
# * TDVP starts at time 12.20...
# * TDVP ends at time 12.30...
# * TDVP starts at time 12.30...
# * TDVP ends at time 12.40...
# * TDVP starts at time 12.40...
# * TDVP ends at time 12.50...
# * TDVP starts at time 12.50...
# * TDVP ends at time 12.60...
# * TDVP starts at time 12.60...
# * TDVP ends at time 12.70...
# * TDVP starts at time 12.70...
# * TDVP ends at time 12.80...
# * TDVP starts at time 12.80...
# * TDVP ends at time 12.90...
# * TDVP starts at time 12.90...
# * TDVP ends at time 13.00...
# * TDVP starts at time 13.00...
# * TDVP ends at time 13.10...
# * TDVP starts at time 13.10...
# * TDVP ends at time 13.20...
# * TDVP starts at time 13.20...
# * TDVP ends at time 13.30...
# * TDVP starts at time 13.30...
# * TDVP ends at time 13.40...
# * TDVP starts at time 13.40...
# * TDVP ends at time 13.50...
# * TDVP starts at time 13.50...
# * TDVP ends at time 13.60...
# * TDVP starts at time 13.60...
# * TDVP ends at time 13.70...
# * TDVP starts at time 13.70...
# * TDVP ends at time 13.80...
# * TDVP starts at time 13.80...
# * TDVP ends at time 13.90...
# * TDVP starts at time 13.90...
# * TDVP ends at time 14.00...
# * TDVP starts at time 14.00...
# * TDVP ends at time 14.10...
# * TDVP starts at time 14.10...
# * TDVP ends at time 14.20...
# * TDVP starts at time 14.20...
# * TDVP ends at time 14.30...
# * TDVP starts at time 14.30...
# * TDVP ends at time 14.40...
# * TDVP starts at time 14.40...
# * TDVP ends at time 14.50...
# * TDVP starts at time 14.50...
# * TDVP ends at time 14.60...
# * TDVP starts at time 14.60...
# * TDVP ends at time 14.70...
# * TDVP starts at time 14.70...
# * TDVP ends at time 14.80...
# * TDVP starts at time 14.80...
# * TDVP ends at time 14.90...
# * TDVP starts at time 14.90...
# * TDVP ends at time 15.00...

# %%
using Plots
plot(Ts, real(Gₜ′), xlabel="t", ylabel="Re(Gₜ)", title="Green's function", label="Re(Gₜe^{-iEt})")
plot!(Ts, imag(Gₜ′), xlabel="t", ylabel="Re(Gₜ)", title="Green's function", label="imag(Gₜe^{-iEt})")
plot!(Ts, real(Gₜ), xlabel="t", ylabel="Re(Gₜ)", title="Green's function", label="Re(Gₜ)")
plot!(Ts, imag(Gₜ), xlabel="t", ylabel="Re(Gₜ)", title="Green's function", label="imag(Gₜ)")
plot!(Ts, abs.(Gₜ), xlabel="t", ylabel="Re(Gₜ)", title="Green's function", label="abs(Gₜ)")
